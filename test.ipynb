# %%
from physical_agent import *
import matplotlib.pyplot as plt

m = IndoorModel()
m.plot_explicitly()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12912/2210034850.py in <module>
#       2 import matplotlib.pyplot as plt
#       3
# ----> 4 m = IndoorModel()
#       5 m.plot_explicitly()
#
# d:\Src\my-test-bed\test-mesa\physical_agent.py in __init__(self, agents_json_path, env_map_path)
#      84                 for ln in lns:
#      85                     parts = ln[1:-1].split(',')
# ---> 86                     waypoints.append([int(parts[0].strip()), int(parts[1].strip())])
#      87             print(waypoints)
#      88             a = PhysicalAgent(i, self)
#
# ValueError: invalid literal for int() with base 10: '215)'

# %%
m.step()
m.plot_explicitly()
